# %% [markdown]
# ## HTML Page Read and Upload

# %%
# Import useful libraries and classes.
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
#html page upload and read in web_page variable.
my_url=  "https://www.flipkart.com/search?p%5B%5D=facets.brand%255B%255D%3DSamsung&sid=tyy%2F4io&sort=recency_desc&wid=1.productCard.PMU_V2_1"
web_page= uReq(my_url)
page_html= web_page.read()
web_page.close()

# %%
page_html
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/><link href="https://img1a.flixcart.com" rel="dns-prefetch"/><link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.376729.css"/><link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_f64bb3.png" as="image"><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon"
# ...

# %% [markdown]
# ## Parsing

# %%
#html parser. It is to beautify the HTML code.
page_soup= soup(page_html)
page_soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ## Extraction of information

# %%
#read class attribute from web page in containers variable.
# Print the length of containers.
containers= page_soup.findAll("div", {"class": "_2kHMtA"})
print(len(containers))
# Out:
# 24

# %%
# Extract the model name of 6th phone in the list.
for container in containers :
        year_mov = container.findAll("div", {"class": "_4rR01T"})
        print(year_mov[0].text)
# Out:
# Samsung Galaxy M31 (Ice Berg Blue, 128 GB)
# Samsung Galaxy M30S (Quartz Green, 128 GB)
# Samsung M31 Prime (Space Black, 128 GB)
# Samsung Galaxy M51 (Celestial Black, 128 GB)
# Samsung Galaxy M51 (Electric Blue, 128 GB)
# Samsung Fold 2 5G (Black, 256 GB)
# Samsung M31 Prime (Ocean Blue, 128 GB)
# Samsung Galaxy S20 FE (Cloud Mint, 128 GB)
# Samsung Galaxy A21s (Black, 128 GB)
# Samsung Galaxy A21s (Blue, 128 GB)
# Samsung Galaxy A21s (Silver, 128 GB)
# Samsung Galaxy S20 FE (Cloud Red, 128 GB)
# Samsung Galaxy S20 FE (Cloud Lavender, 128 GB)
# Samsung Galaxy S20 FE (Cloud Navy, 128 GB)
# Samsung Galaxy S20 FE (Cloud White, 128 GB)
# Samsung GALAXY M51 (ELECTRIC BLUE, 128 GB)
# Samsung GALAXY M51 (Celestial Black, 128 GB)
# Samsung Galaxy F41 (Fusion Green, 64 GB)
# Samsung Galaxy F41 (Fusion Black, 64 GB)
# Samsung Galaxy F41 (Fusion Blue, 128 GB)
# Samsung Galaxy F41 (Fusion Green, 128 GB)
# Samsung Galaxy F41 (Fusion Blue, 64 GB)
# Samsung Galaxy F41 (Fusion Black, 128 GB)
# ...

# %%
year_mov = containers[5].findAll("div", {"class": "_4rR01T"})
print(year_mov[0].text)

# %%
# how many elements does 'tVe95H' class contained in it?
ss= page_soup.findAll("div", {"class": "tVe95H"})
print(len(ss))
# Out:
# 0

# %%
# Read the camera specification of 8th phone in the list.
spec= page_soup.findAll("div", {"class": "fMghEO"})
Camera=spec[0].findAll("li" , {"class" : "rgWa7D"})
print(Camera[2].text)
# Out:
# 64MP + 8MP + 5MP + 5MP | 32MP Front Camera
